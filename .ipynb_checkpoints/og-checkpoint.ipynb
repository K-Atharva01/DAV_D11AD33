# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
Data = pd.read_csv("/content/sample_data/report_2018-2019.csv")
Data.head()
# Out:
#    Overall rank Country or region  Year  Score  GDP per capita  \
# 0           154       Afghanistan  2019  3.203           0.350
# 1           145       Afghanistan  2018  3.632           0.332
# 2           107           Albania  2019  4.719           0.947
# 3           112           Albania  2018  4.586           0.916
# 4            88           Algeria  2019  5.211           1.002
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.517                    0.361                         0.000
# 1           0.537                    0.255                         0.085
# 2           0.848                    0.874                         0.383
# 3           0.817                    0.790                         0.419
# 4           1.160                    0.785                         0.086
#
#    Generosity  Perceptions of corruption
# 0       0.158                      0.025
# 1       0.191                      0.036
# 2       0.178                      0.027
# 3       0.149                      0.032
# 4       0.073                      0.114

# %%
df = pd.DataFrame(Data,columns= ["Score","GDP per capita","Social support","Healthy life expectancy","Freedom to make life choices","Generosity","Perceptions of corruption"])
df.head()
# Out:
#    Score  GDP per capita  Social support  Healthy life expectancy  \
# 0  3.203           0.350           0.517                    0.361
# 1  3.632           0.332           0.537                    0.255
# 2  4.719           0.947           0.848                    0.874
# 3  4.586           0.916           0.817                    0.790
# 4  5.211           1.002           1.160                    0.785
#
#    Freedom to make life choices  Generosity  Perceptions of corruption
# 0                         0.000       0.158                      0.025
# 1                         0.085       0.191                      0.036
# 2                         0.383       0.178                      0.027
# 3                         0.419       0.149                      0.032
# 4                         0.086       0.073                      0.114

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      Score  GDP per capita  Social support  Healthy life expectancy  \
# 0    3.203           0.350           0.517                    0.361
# 1    3.632           0.332           0.537                    0.255
# 2    4.719           0.947           0.848                    0.874
# 3    4.586           0.916           0.817                    0.790
# 4    5.211           1.002           1.160                    0.785
# ..     ...             ...             ...                      ...
# 307  3.355           0.442           1.073                    0.343
# 308  4.107           0.578           1.058                    0.426
# 309  4.377           0.562           1.047                    0.295
# 310  3.663           0.366           1.114                    0.433
# 311  3.692           0.357           1.094                    0.248
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 0                           0.000       0.158                      0.025
# 1                           0.085       0.191                      0.036
# 2                           0.383       0.178                      0.027
# 3                           0.419       0.149                      0.032
# 4                           0.086       0.073                      0.114
# ..                            ...         ...                        ...
# 307                         0.244       0.083                      0.064
# 308                         0.431       0.247                      0.087
# 309                         0.503       0.221                      0.082
# 310                         0.361       0.151                      0.089
# 311                         0.406       0.132                      0.099
#
# [312 rows x 7 columns]>

# %%
df.isnull().sum()
# Out:
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %%
columns = ["Score","GDP per capita","Social support","Healthy life expectancy","Freedom to make life choices","Generosity","Perceptions of corruption"]
df1 = df[columns]

sns.set(style="ticks", color_codes=True)
pair_plot = sns.pairplot(df1)
plt.suptitle('Pair Plot of Happiness Index', y=1.02)
plt.show()

# %%
x = df["GDP per capita"].values.reshape(-1,1)
y = df["Score"].values.reshape(-1,1)

# %%
plt.figure(figsize=(10,8),dpi = 80)
plt.scatter(x,y)
plt.xlabel("GDP per capita",size = 16)
plt.ylabel("Score",size = 16)
plt.show()

# %%
df.loc[(df['GDP per capita'] >= 2.0)]
# Out:
#      Score  GDP per capita  Social support  Healthy life expectancy  \
# 293  6.774           2.096           0.776                     0.67
#
#      Freedom to make life choices  Generosity  Perceptions of corruption
# 293                         0.284       0.186                      0.182

# %%
df.drop(293, axis=0, inplace=True)

# %%
x = df["GDP per capita"].values.reshape(-1,1)
y = df["Score"].values.reshape(-1,1)

# %%
plt.figure(figsize=(10,8),dpi = 80)
plt.scatter(x,y)
plt.xlabel("GDP per capita",size = 16)
plt.ylabel("Score",size = 16)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train , x_test, y_train, y_test
# Out:
# (array([[0.62 ],
#         [1.21 ],
#         [0.359],
#         [0.668],
#         [0.889],
#         [0.53 ],
#         [0.96 ],
#         [0.931],
#         [0.73 ],
#         [0.657],
#         [0.776],
#         [1.039],
#         [1.42 ],
#         [1.029],
#         [0.764],
#         [0.512],
#         [1.263],
#         [0.259],
#         [0.138],
#         [1.5  ],
#         [0.191],
#         [1.293],
#         [0.775],
#         [1.01 ],
#         [0.755],
#         [0.37 ],
#         [0.   ],
#         [0.562],
#         [0.551],
#         [0.913],
#         [0.719],
#         [0.322],
#         [1.233],
#         [1.043],
#         [0.816],
#         [0.455],
#         [0.45 ],
#         [1.34 ],
#         [1.115],
#         [1.004],
#         [0.986],
#         [1.024],
#         [1.131],
#         [0.489],
#         [1.231],
#         [1.155],
#         [1.405],
#         [1.263],
#         [0.751],
#         [0.948],
#         [0.076],
#         [1.379],
#         [1.499],
#         [1.338],
#         [1.286],
#         [1.373],
#         [1.143],
#         [0.831],
#         [0.308],
#         [0.918],
#         [0.987],
#         [1.448],
#         [0.605],
#         [0.131],
#         [0.442],
#         [1.398],
#         [0.57 ],
#         [0.879],
#         [0.855],
#         [1.244],
#         [1.264],
#         [1.092],
#         [1.246],
#         [1.12 ],
#         [0.855],
#         [1.201],
#         [0.557],
#         [0.721],
#         [1.016],
#         [1.223],
#         [1.529],
#         [1.051],
#         [1.151],
#         [0.947],
#         [1.343],
#         [0.874],
#         [1.017],
#         [1.1  ],
#         [0.807],
#         [0.619],
#         [1.301],
#         [1.351],
#         [0.796],
#         [1.237],
#         [0.306],
#         [0.315],
#         [1.503],
#         [0.274],
#         [0.819],
#         [1.365],
#         [1.684],
#         [1.034],
#         [1.229],
#         [0.336],
#         [1.176],
#         [0.985],
#         [1.34 ],
#         [1.017],
#         [0.813],
#         [1.161],
#         [0.882],
#         [1.301],
#         [0.541],
#         [1.038],
#         [0.024],
#         [0.853],
#         [0.835],
#         [1.09 ],
#         [1.183],
#         [0.314],
#         [1.324],
#         [1.649],
#         [0.837],
#         [0.393],
#         [0.715],
#         [0.493],
#         [1.456],
#         [0.35 ],
#         [0.275],
#         [0.921],
#         [1.181],
#         [0.682],
#         [1.452],
#         [0.781],
#         [0.385],
#         [0.611],
#         [1.004],
#         [0.673],
#         [1.187],
#         [1.219],
#         [0.652],
#         [1.266],
#         [1.372],
#         [0.578],
#         [1.268],
#         [1.016],
#         [0.378],
#         [1.116],
#         [1.002],
#         [1.043],
#         [0.945],
#         [0.96 ],
#         [1.609],
#         [0.934],
#         [1.183],
#         [1.173],
#         [0.682],
#         [0.642],
#         [1.294],
#         [1.294],
#         [0.96 ],
#         [1.073],
#         [1.229],
#         [0.476],
#         [0.069],
#         [0.574],
#         [1.258],
#         [0.073],
#         [0.331],
#         [1.01 ],
#         [1.148],
#         [1.149],
#         [0.965],
#         [1.356],
#         [0.689],
#         [1.438],
#         [0.794],
#         [1.403],
#         [0.983],
#         [0.677],
#         [1.054],
#         [0.94 ],
#         [0.996],
#         [1.355],
#         [1.303],
#         [1.341],
#         [0.535],
#         [0.886],
#         [0.493],
#         [1.188],
#         [0.9  ],
#         [0.694],
#         [1.197],
#         [0.091],
#         [1.112],
#         [0.198],
#         [1.251],
#         [0.344],
#         [0.358],
#         [0.332],
#         [1.33 ],
#         [0.885],
#         [0.696],
#         [1.041],
#         [0.811],
#         [1.057],
#         [0.35 ],
#         [1.387],
#         [0.975],
#         [1.376],
#         [1.305],
#         [0.474],
#         [0.262],
#         [0.287],
#         [1.327],
#         [1.093],
#         [0.256],
#         [1.159],
#         [0.026],
#         [1.27 ],
#         [0.204],
#         [0.366],
#         [0.801],
#         [1.221],
#         [0.985],
#         [1.365],
#         [0.332],
#         [0.96 ],
#         [1.067],
#         [1.238],
#         [1.05 ],
#         [0.71 ],
#         [1.333],
#         [0.337],
#         [0.72 ],
#         [0.569],
#         [1.148],
#         [0.592],
#         [1.34 ],
#         [0.657],
#         [1.059],
#         [0.357],
#         [0.532],
#         [0.779],
#         [1.269],
#         [0.323],
#         [1.368],
#         [0.8  ]]),
#  array([[0.82 ],
#         [0.85 ],
#         [0.989],
#         [0.274],
#         [0.807],
#         [0.094],
#         [1.036],
#         [0.914],
#         [1.572],
#         [0.549],
#         [1.015],
#         [1.576],
#         [1.124],
#         [0.562],
#         [1.052],
#         [0.793],
#         [0.979],
#         [0.472],
#         [0.959],
#         [0.186],
#         [1.383],
#         [0.38 ],
#         [0.822],
#         [0.689],
#         [0.982],
#         [1.3  ],
#         [1.171],
#         [0.915],
#         [1.433],
#         [0.   ],
#         [0.642],
#         [0.916],
#         [0.806],
#         [0.949],
#         [0.308],
#         [1.154],
#         [0.549],
#         [1.362],
#         [1.396],
#         [0.899],
#         [0.046],
#         [1.324],
#         [1.07 ],
#         [0.268],
#         [0.745],
#         [0.425],
#         [1.221],
#         [1.092],
#         [0.332],
#         [0.912],
#         [1.38 ],
#         [0.429],
#         [1.474],
#         [1.2  ],
#         [0.685],
#         [1.162],
#         [0.741],
#         [1.361],
#         [0.446],
#         [1.488],
#         [1.206],
#         [1.044],
#         [1.276]]),
#  array([[5.504],
#         [6.173],
#         [3.334],
#         [6.141],
#         [5.973],
#         [5.131],
#         [6.26 ],
#         [5.192],
#         [3.795],
#         [5.64 ],
#         [5.779],
#         [5.483],
#         [7.487],
#         [5.191],
#         [4.796],
#         [4.509],
#         [5.718],
#         [3.999],
#         [4.628],
#         [6.021],
#         [3.41 ],
#         [6.489],
#         [5.524],
#         [7.072],
#         [4.015],
#         [4.447],
#         [4.668],
#         [4.456],
#         [5.261],
#         [4.166],
#         [6.096],
#         [4.161],
#         [6.711],
#         [5.208],
#         [4.321],
#         [3.303],
#         [4.681],
#         [6.965],
#         [5.321],
#         [5.603],
#         [6.419],
#         [5.201],
#         [6.476],
#         [3.802],
#         [6.192],
#         [5.432],
#         [5.43 ],
#         [6.046],
#         [5.752],
#         [5.285],
#         [3.495],
#         [6.371],
#         [7.021],
#         [6.105],
#         [6.354],
#         [6.985],
#         [5.79 ],
#         [5.89 ],
#         [4.35 ],
#         [4.471],
#         [5.197],
#         [6.977],
#         [4.139],
#         [4.166],
#         [3.355],
#         [6.886],
#         [4.49 ],
#         [4.639],
#         [5.743],
#         [7.19 ],
#         [6.   ],
#         [5.011],
#         [6.198],
#         [5.888],
#         [5.662],
#         [5.758],
#         [4.356],
#         [4.19 ],
#         [5.636],
#         [6.192],
#         [6.343],
#         [5.523],
#         [5.81 ],
#         [4.719],
#         [7.495],
#         [4.441],
#         [5.347],
#         [4.548],
#         [5.631],
#         [3.462],
#         [6.814],
#         [7.555],
#         [5.082],
#         [5.893],
#         [2.853],
#         [3.582],
#         [6.825],
#         [3.933],
#         [5.89 ],
#         [6.441],
#         [6.374],
#         [7.167],
#         [5.835],
#         [4.286],
#         [6.123],
#         [5.566],
#         [7.272],
#         [3.59 ],
#         [5.082],
#         [6.322],
#         [6.1  ],
#         [5.895],
#         [4.671],
#         [6.488],
#         [3.083],
#         [4.34 ],
#         [5.681],
#         [5.891],
#         [5.648],
#         [4.424],
#         [6.592],
#         [6.374],
#         [4.906],
#         [4.883],
#         [5.103],
#         [4.41 ],
#         [7.594],
#         [3.203],
#         [4.085],
#         [4.461],
#         [5.287],
#         [4.308],
#         [7.48 ],
#         [6.382],
#         [4.39 ],
#         [4.996],
#         [6.3  ],
#         [4.812],
#         [5.94 ],
#         [5.948],
#         [5.472],
#         [5.875],
#         [7.228],
#         [4.107],
#         [7.324],
#         [6.072],
#         [4.141],
#         [5.945],
#         [5.211],
#         [4.437],
#         [5.386],
#         [5.697],
#         [7.09 ],
#         [5.663],
#         [5.373],
#         [5.809],
#         [4.559],
#         [4.743],
#         [5.915],
#         [6.223],
#         [4.707],
#         [6.388],
#         [5.762],
#         [3.231],
#         [4.245],
#         [4.7  ],
#         [6.118],
#         [3.975],
#         [4.587],
#         [4.456],
#         [5.483],
#         [6.321],
#         [5.358],
#         [6.923],
#         [3.462],
#         [5.43 ],
#         [6.253],
#         [6.375],
#         [5.274],
#         [5.653],
#         [4.933],
#         [4.724],
#         [4.806],
#         [7.314],
#         [7.307],
#         [7.139],
#         [4.975],
#         [4.519],
#         [5.467],
#         [5.41 ],
#         [4.592],
#         [6.105],
#         [5.952],
#         [2.905],
#         [6.43 ],
#         [4.417],
#         [6.31 ],
#         [3.964],
#         [4.301],
#         [3.632],
#         [7.328],
#         [4.419],
#         [5.265],
#         [3.488],
#         [4.212],
#         [4.799],
#         [4.35 ],
#         [7.343],
#         [5.398],
#         [7.246],
#         [7.632],
#         [5.199],
#         [3.774],
#         [3.38 ],
#         [5.886],
#         [6.379],
#         [4.571],
#         [6.444],
#         [3.083],
#         [6.627],
#         [4.466],
#         [3.663],
#         [5.208],
#         [5.339],
#         [6.125],
#         [7.278],
#         [3.408],
#         [4.722],
#         [5.323],
#         [6.149],
#         [6.008],
#         [4.36 ],
#         [7.054],
#         [3.254],
#         [4.623],
#         [4.944],
#         [5.933],
#         [4.657],
#         [7.769],
#         [4.696],
#         [4.707],
#         [3.692],
#         [4.5  ],
#         [5.254],
#         [6.852],
#         [3.597],
#         [6.446],
#         [6.436]]),
#  array([[4.332],
#         [4.559],
#         [5.246],
#         [3.973],
#         [5.956],
#         [4.418],
#         [4.758],
#         [5.125],
#         [6.262],
#         [5.044],
#         [5.425],
#         [6.91 ],
#         [6.293],
#         [4.377],
#         [5.247],
#         [4.103],
#         [5.295],
#         [3.808],
#         [5.185],
#         [3.587],
#         [7.6  ],
#         [4.534],
#         [5.161],
#         [5.155],
#         [5.302],
#         [6.726],
#         [5.62 ],
#         [5.129],
#         [6.892],
#         [4.982],
#         [5.86 ],
#         [4.586],
#         [6.167],
#         [4.366],
#         [4.516],
#         [5.358],
#         [4.433],
#         [6.199],
#         [7.488],
#         [5.093],
#         [3.775],
#         [6.927],
#         [6.595],
#         [4.374],
#         [6.174],
#         [4.88 ],
#         [5.693],
#         [6.086],
#         [4.189],
#         [6.028],
#         [7.494],
#         [4.631],
#         [6.083],
#         [5.739],
#         [5.529],
#         [6.07 ],
#         [5.175],
#         [7.441],
#         [4.913],
#         [7.554],
#         [6.182],
#         [5.525],
#         [7.139]]))

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test)
y_predict = y_predict.round(0)
y_predict
# Out:
# array([[5.],
#        [5.],
#        [6.],
#        [4.],
#        [5.],
#        [3.],
#        [6.],
#        [5.],
#        [7.],
#        [5.],
#        [6.],
#        [7.],
#        [6.],
#        [5.],
#        [6.],
#        [5.],
#        [6.],
#        [4.],
#        [6.],
#        [4.],
#        [7.],
#        [4.],
#        [5.],
#        [5.],
#        [6.],
#        [6.],
#        [6.],
#        [5.],
#        [7.],
#        [3.],
#        [5.],
#        [5.],
#        [5.],
#        [5.],
#        [4.],
#        [6.],
#        [5.],
#        [6.],
#        [7.],
#        [5.],
#        [3.],
#        [6.],
#        [6.],
#        [4.],
#        [5.],
#        [4.],
#        [6.],
#        [6.],
#        [4.],
#        [5.],
#        [7.],
#        [4.],
#        [7.],
#        [6.],
#        [5.],
#        [6.],
#        [5.],
#        [6.],
#        [4.],
#        [7.],
#        [6.],
#        [6.],
#        [6.]])

# %%
x_test = np.reshape(x_test,(x_test.shape[0]))
y_test = np.reshape(y_test,(y_test.shape[0]))
y_predict = np.reshape(y_predict,(y_predict.shape[0]))
df1 = pd.DataFrame({"X":x_test,"Actual":y_test,"Predict":y_predict})
df1
# Out:
#         X  Actual  Predict
# 0   0.820   4.332      5.0
# 1   0.850   4.559      5.0
# 2   0.989   5.246      6.0
# 3   0.274   3.973      4.0
# 4   0.807   5.956      5.0
# ..    ...     ...      ...
# 58  0.446   4.913      4.0
# 59  1.488   7.554      7.0
# 60  1.206   6.182      6.0
# 61  1.044   5.525      6.0
# 62  1.276   7.139      6.0
#
# [63 rows x 3 columns]

# %%
from sklearn import metrics
print("Explaind variance:", metrics.explained_variance_score(y_test,y_predict))
print("Max error:",metrics.max_error(y_test,y_predict))
print("Mean absolute error:",metrics.mean_absolute_error(y_test,y_predict))
print("Mean squared error:",metrics.mean_squared_error(y_test,y_predict,squared=True))

print("R-2 score:",metrics.r2_score(y_test,y_predict))
# Out:
# Explaind variance: 0.5438512147029182
# Max error: 1.9820000000000002
# Mean absolute error: 0.5863174603174603
# Root mean squared error: 0.7071542343160445
# Mean squared error: 0.5000671111111112
# Mean squared logarithmic error: 0.013934240161363116
# R-2 score: 0.5275881576138319

# %%
install.packages("ggplot2")
install.packages("dplyr")
install.packages("GGally")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘labelled’, ‘broom.helpers’, ‘patchwork’, ‘ggstats’, ‘plyr’

# %%
library(ggplot2)
library(dplyr)
library(GGally)
# Out:
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %%
data <- read.csv("/content/sample_data/report_2018-2019.csv")
data
# Out:
#     Overall.rank Country.or.region    Year Score GDP.per.capita Social.support
# 1   154          Afghanistan          2019 3.203 0.350          0.517
# 2   145          Afghanistan          2018 3.632 0.332          0.537
# 3   107          Albania              2019 4.719 0.947          0.848
# 4   112          Albania              2018 4.586 0.916          0.817
# 5    88          Algeria              2019 5.211 1.002          1.160
# 6    84          Algeria              2018 5.295 0.979          1.154
# 7   142          Angola               2018 3.795 0.730          1.125
# 8    47          Argentina            2019 6.086 1.092          1.432
# 9    29          Argentina            2018 6.388 1.073          1.468
# 10  116          Armenia              2019 4.559 0.850          1.055
# 11  129          Armenia              2018 4.321 0.816          0.990
# 12   11          Australia            2019 7.228 1.372          1.548
# 13   10          Australia            2018 7.272 1.340          1.573
# 14   10          Austria              2019 7.246 1.376          1.475
# 15   12          Austria              2018 7.139 1.341          1.504
# 16   90          Azerbaijan           2019 5.208 1.043          1.147
# 17   87          Azerbaijan           2018 5.201 1.024          1.161
# 18   37          Bahrain              2019 6.199 1.362          1.368
# 19   43          Bahrain              2018 6.105 1.338          1.366
# 20  125          Bangladesh           2019 4.456 0.562          0.928
# 21  115          Bangladesh           2018 4.500 0.532          0.850
# 22   81          Belarus              2019 5.323 1.067          1.465
# 23   73          Belarus              2018 5.483 1.039          1.498
# 24   18          Belgium              2019 6.923 1.356          1.504
# 25   16          Belgium              2018 6.927 1.324          1.483
# 26   49          Belize               2018 5.956 0.807          1.101
# 27  102          Benin                2019 4.883 0.393          0.437
# 28  136          Benin                2018 4.141 0.378          0.372
# 29   95          Bhutan               2019 5.082 0.813          1.321
# 30   97          Bhutan               2018 5.082 0.796          1.335
# ⋮   ⋮            ⋮                    ⋮    ⋮     ⋮              ⋮
# 283 124          Tunisia              2019 4.461 0.921          1.000
# 284 111          Tunisia              2018 4.592 0.900          0.906
# 285  79          Turkey               2019 5.373 1.183          1.360
# 286  74          Turkey               2018 5.483 1.148          1.380
# 287  87          Turkmenistan         2019 5.247 1.052          1.538
# 288  68          Turkmenistan         2018 5.636 1.016          1.533
# 289 136          Uganda               2019 4.189 0.332          1.069
# 290 135          Uganda               2018 4.161 0.322          1.090
# 291 133          Ukraine              2019 4.332 0.820          1.390
# 292 138          Ukraine              2018 4.103 0.793          1.413
# 293  21          United Arab Emirates 2019 6.825 1.503          1.310
# 294  20          United Arab Emirates 2018 6.774 2.096          0.776
# 295  15          United Kingdom       2019 7.054 1.333          1.538
# 296  11          United Kingdom       2018 7.190 1.244          1.433
# 297  19          United States        2019 6.892 1.433          1.457
# 298  18          United States        2018 6.886 1.398          1.471
# 299  33          Uruguay              2019 6.293 1.124          1.465
# 300  31          Uruguay              2018 6.379 1.093          1.459
# 301  41          Uzbekistan           2019 6.174 0.745          1.529
# 302  44          Uzbekistan           2018 6.096 0.719          1.584
# 303 108          Venezuela            2019 4.707 0.960          1.427
# 304 102          Venezuela            2018 4.806 0.996          1.469
# 305  94          Vietnam              2019 5.175 0.741          1.346
# 306  95          Vietnam              2018 5.103 0.715          1.365
# 307 151          Yemen                2019 3.380 0.287          1.163
# 308 152          Yemen                2018 3.355 0.442          1.073
# 309 138          Zambia               2019 4.107 0.578          1.058
# 310 125          Zambia               2018 4.377 0.562          1.047
# 311 146          Zimbabwe             2019 3.663 0.366          1.114
# 312 144          Zimbabwe             2018 3.692 0.357          1.094
#     Healthy.life.expectancy Freedom.to.make.life.choices Generosity
# 1   0.361                   0.000                        0.158
# 2   0.255                   0.085                        0.191
# 3   0.874                   0.383                        0.178
# 4   0.790                   0.419                        0.149
# 5   0.785                   0.086                        0.073
# 6   0.687                   0.077                        0.055
# 7   0.269                   0.000                        0.079
# 8   0.881                   0.471                        0.066
# 9   0.744                   0.570                        0.062
# 10  0.815                   0.283                        0.095
# 11  0.666                   0.260                        0.077
# 12  1.036                   0.557                        0.332
# 13  0.910                   0.647                        0.361
# 14  1.016                   0.532                        0.244
# 15  0.891                   0.617                        0.242
# 16  0.769                   0.351                        0.035
# 17  0.603                   0.430                        0.031
# 18  0.871                   0.536                        0.255
# 19  0.698                   0.594                        0.243
# 20  0.723                   0.527                        0.166
# 21  0.579                   0.580                        0.153
# 22  0.789                   0.235                        0.094
# 23  0.700                   0.307                        0.101
# 24  0.986                   0.473                        0.160
# 25  0.894                   0.583                        0.188
# 26  0.474                   0.593                        0.183
# 27  0.397                   0.349                        0.175
# 28  0.240                   0.440                        0.163
# 29  0.604                   0.457                        0.370
# 30  0.527                   0.541                        0.364
# ⋮   ⋮                       ⋮                            ⋮
# 283 0.815                   0.167                        0.059
# 284 0.690                   0.271                        0.040
# 285 0.808                   0.195                        0.083
# 286 0.686                   0.324                        0.106
# 287 0.657                   0.394                        0.244
# 288 0.517                   0.417                        0.199
# 289 0.443                   0.356                        0.252
# 290 0.237                   0.450                        0.259
# 291 0.739                   0.178                        0.187
# 292 0.609                   0.163                        0.187
# 293 0.825                   0.598                        0.262
# 294 0.670                   0.284                        0.186
# 295 0.996                   0.450                        0.348
# 296 0.888                   0.464                        0.262
# 297 0.874                   0.454                        0.280
# 298 0.819                   0.547                        0.291
# 299 0.891                   0.523                        0.127
# 300 0.771                   0.625                        0.130
# 301 0.756                   0.631                        0.322
# 302 0.605                   0.724                        0.328
# 303 0.805                   0.154                        0.064
# 304 0.657                   0.133                        0.056
# 305 0.851                   0.543                        0.147
# 306 0.702                   0.618                        0.177
# 307 0.463                   0.143                        0.108
# 308 0.343                   0.244                        0.083
# 309 0.426                   0.431                        0.247
# 310 0.295                   0.503                        0.221
# 311 0.433                   0.361                        0.151
# 312 0.248                   0.406                        0.132
#     Perceptions.of.corruption
# 1   0.025
# 2   0.036
# 3   0.027
# 4   0.032
# 5   0.114
# 6   0.135
# 7   0.061
# 8   0.050
# 9   0.054
# 10  0.064
# 11  0.028
# 12  0.290
# 13  0.302
# 14  0.226
# 15  0.224
# 16  0.182
# 17  0.176
# 18  0.110
# 19  0.123
# 20  0.143
# 21  0.144
# 22  0.142
# 23  0.154
# 24  0.210
# 25  0.240
# 26  0.089
# 27  0.082
# 28  0.067
# 29  0.167
# 30  0.171
# ⋮   ⋮
# 283 0.055
# 284 0.063
# 285 0.106
# 286 0.109
# 287 0.028
# 288 0.037
# 289 0.060
# 290 0.061
# 291 0.010
# 292 0.011
# 293 0.182
# 294 0.182
# 295 0.278
# 296 0.082
# 297 0.128
# 298 0.133
# 299 0.150
# 300 0.155
# 301 0.240
# 302 0.259
# 303 0.047
# 304 0.052
# 305 0.073
# 306 0.079
# 307 0.077
# 308 0.064
# 309 0.087
# 310 0.082
# 311 0.089
# 312 0.099

# %%
summary(data)
# Out:
#   Overall.rank    Country.or.region       Year          Score
#  Min.   :  1.00   Length:312         Min.   :2018   Min.   :2.853
#  1st Qu.: 39.75   Class :character   1st Qu.:2018   1st Qu.:4.514
#  Median : 78.50   Mode  :character   Median :2018   Median :5.380
#  Mean   : 78.50                      Mean   :2018   Mean   :5.392
#  3rd Qu.:117.25                      3rd Qu.:2019   3rd Qu.:6.176
#  Max.   :156.00                      Max.   :2019   Max.   :7.769
#  GDP.per.capita   Social.support  Healthy.life.expectancy
#  Min.   :0.0000   Min.   :0.000   Min.   :0.0000
#  1st Qu.:0.6095   1st Qu.:1.056   1st Qu.:0.4883
#  Median :0.9600   Median :1.266   Median :0.6990
#  Mean   :0.8983   Mean   :1.211   Mean   :0.6613
#  3rd Qu.:1.2195   3rd Qu.:1.458   3rd Qu.:0.8580
#  Max.   :2.0960   Max.   :1.644   Max.   :1.1410
#  Freedom.to.make.life.choices   Generosity     Perceptions.of.corruption
#  Min.   :0.0000               Min.   :0.0000   Min.   :0.0000
#  1st Qu.:0.3225               1st Qu.:0.1087   1st Qu.:0.0500
#  Median :0.4495               Median :0.1755   Median :0.0820
#  Mean   :0.4235               Mean   :0.1829   Mean   :0.1115
#  3rd Qu.:0.5403               3rd Qu.:0.2450   3rd Qu.:0.1412
#  Max.   :0.7240               Max.   :0.5980   Max.   :0.4570

# %%
ggpairs(data)
# Out:
# Error in stop_if_high_cardinality(data, columns, cardinality_threshold): Column 'Country.or.region' has more levels (160) than the threshold (15) allowed.
# Please remove the column or increase the 'cardinality_threshold' parameter. Increasing the cardinality_threshold may produce long processing times
# Traceback:
#
# 1. ggpairs(data)
# 2. stop_if_high_cardinality(data, columns, cardinality_threshold)
# 3. stop("Column '", col, "' has more levels (", level_length, ")",
#  .     " than the threshold (", threshold, ") allowed.\n", "Please remove the column or increase the 'cardinality_threshold' parameter. Increasing the cardinality_threshold may produce long processing times")
